# %%
import pandas as pd

# %%
path = '../session2/data_retail'

path_customers = f'{path}/customers'
path_orders = f'{path}/orders'
path_order_items = f'{path}/order_items'
path_products = f'{path}/products'
path_categories = f'{path}/categories'
path_departments = f'{path}/departments'

# %%
df_customers = pd.read_csv(path_customers,sep='|', header=None)
df_orders = pd.read_csv(path_orders,sep='|', header=None)
df_order_items = pd.read_csv(path_order_items,sep='|', header=None)
df_products = pd.read_csv(path_products,sep='|', header=None)
df_categories = pd.read_csv(path_categories,sep='|', header=None, names=['id_categories','id_grupo_categories','desc_categories'])
df_departments = pd.read_csv(path_departments,sep='|', header=None)

# %%
df_departments.columns =['id_department','desc_deparment']

# %%
df_departments
# Out:
#    id_department desc_deparment
# 0              2        Fitness
# 1              3       Footwear
# 2              4        Apparel
# 3              5           Golf
# 4              6       Outdoors
# 5              7       Fan Shop

# %%
df_categories.head()
# Out:
#    id_categorie  id_grupo_Categoria       desc_categoria
# 0             1                   2             Football
# 1             2                   2               Soccer
# 2             3                   2  Baseball & Softball
# 3             4                   2           Basketball
# 4             5                   2             Lacrosse

# %%
#cambiar nombres de columnas
df_categories.columns = ['id_categorie','id_grupo_Categoria','desc_categoria']

# %%
df_categories.head()
# Out:
#    id_categorie  id_grupo_Categoria       desc_categoria
# 0             1                   2             Football
# 1             2                   2               Soccer
# 2             3                   2  Baseball & Softball
# 3             4                   2           Basketball
# 4             5                   2             Lacrosse

# %%
#df_departments
df_departments['desc_deparment'].duplicated().any()
# Out:
# np.False_

# %%
def validar_department(df, columaName):
    if df[columaName].duplicated().any():
        print(f'Hay departamentos duplicados en el dataframe en la columna {columaName}')
        exit(1)
    else:
        print(f'No existen duplicados')

#validar_department(df_departments,'desc_deparment')
validar_department(df_categories,'id_grupo_categories')
# Out:
# Hay departamentos duplicados en el dataframe en la columna id_grupo_categories

# %%
idValidos = set(df_departments['id_department'])
idValidos
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
df_categories['id_grupo_categories'].isin(idValidos).all()
#any() hay uno verdadero?
#all() todos son verdadedos?
# Out:
# np.False_

# %%
df_departments.merge(df_categories,left_on='id_department', right_on='id_grupo_categories', how='left')
# Out:
#     id_department desc_deparment  id_categories  id_grupo_categories  \
# 0               2        Fitness              1                    2
# 1               2        Fitness              2                    2
# 2               2        Fitness              3                    2
# 3               2        Fitness              4                    2
# 4               2        Fitness              5                    2
# 5               2        Fitness              6                    2
# 6               2        Fitness              7                    2
# 7               2        Fitness              8                    2
# 8               3       Footwear              9                    3
# 9               3       Footwear             10                    3
# 10              3       Footwear             11                    3
# 11              3       Footwear             12                    3
# 12              3       Footwear             13                    3
# ...

# %%
#cuando las llaves primaria y la llave forania tiene el mismo nombre, se puede usar este query
df_departments.merge(df_categories,on=['id_department','id_grupo_categories'], how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_d/8zfrm8wd1jz0jqykf_5jsdq80000gn/T/ipykernel_24379/2180522454.py in ?()
#       1 #cuando las llaves primaria y la llave forania tiene el mismo nombre, se puede usar este query
# ----> 2 df_departments.merge(df_categories,on=['id_department','id_grupo_categories'], how='left')
#
# /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# ...

# %%
#escribir datos en planos
df_departments.to_csv('df_deparments.csv', index=False)

# %%
df_departments.to_json('df_deparments.json', orient='records', indent=4)

# %%
#escribir en base de datos
import sqlalchemy as db
import pandas as pd
engine = db.create_engine('mysql+mysqlconnector://root:root@localhost:3310/retail_db')
con = engine.connect()

# %%
df_departments.to_sql('departments_2', con=con, index=False)
# Out:
# 6

# %%
df_prueba = pd.read_sql_table('departments_2',con=con)
df_prueba
# Out:
#    id_department desc_deparment
# 0              2        Fitness
# 1              3       Footwear
# 2              4        Apparel
# 3              5           Golf
# 4              6       Outdoors
# 5              7       Fan Shop
