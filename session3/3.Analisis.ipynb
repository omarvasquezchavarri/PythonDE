# %%
#escribir en base de datos
import sqlalchemy as db
import pandas as pd
engine = db.create_engine('mysql+mysqlconnector://root:root@localhost:3310/retail_db')
con = engine.connect()

# %%
df_customers = pd.read_sql_table('customers', con=con)
df_products = pd.read_sql_table('products', con=con)

# %%
df_customers['customer_id'].nunique()
# Out:
# 12435

# %%
df_customers['customer_state'].value_counts()
# Out:
# customer_state
# PR    4771
# CA    2012
# NY     775
# TX     635
# IL     523
# FL     374
# OH     276
# PA     261
# MI     254
# NJ     219
# AZ     213
# GA     169
# MD     164
# NC     150
# VA     136
# CO     122
# OR     119
# MA     113
# TN     104
# NV     103
# MO      92
# HI      87
# NM      73
# CT      73
# WA      72
# UT      69
# WI      64
# LA      63
# DC      42
# SC      41
# IN      40
# MN      39
# KY      35
# KS      29
# DE      23
# OK      19
# WV      16
# RI      15
# ND      14
# AR      12
# ID       9
# MT       7
# IA       5
# AL       3
# Name: count, dtype: int64

# %%
df_products.head()
# Out:
#    product_id  product_category_id  \
# 0           1                    2
# 1           2                    2
# 2           3                    2
# 3           4                    2
# 4           5                    2
#
#                                     product_name product_description  \
# 0  Quest Q64 10 FT. x 10 FT. Slant Leg Instant U
# 1  Under Armour Men's Highlight MC Football Clea
# 2  Under Armour Men's Renegade D Mid Football Cl
# 3  Under Armour Men's Renegade D Mid Football Cl
# 4  Riddell Youth Revolution Speed Custom Footbal
#
#    product_price                                      product_image
# 0          59.98  http://images.acmesports.sports/Quest+Q64+10+F...
# 1         129.99  http://images.acmesports.sports/Under+Armour+M...
# 2          89.99  http://images.acmesports.sports/Under+Armour+M...
# 3          89.99  http://images.acmesports.sports/Under+Armour+M...
# 4         199.99  http://images.acmesports.sports/Riddell+Youth+...

# %%
#Precio maximo y minimo de productos
#df_products['product_price'].idxmax()
df_products['product_price'].idxmin()
# Out:
# 37

# %%
#df_products.nlargest(10,'product_price')
df_products.nsmallest(10,'product_price')
# Out:
#       product_id  product_category_id  \
# 37            38                    3
# 387          388                   18
# 413          414                   19
# 516          517                   24
# 546          547                   25
# 933          934                   42
# 1283        1284                   57
# 623          624                   29
# 814          815                   37
# 335          336                   15
#
#                                        product_name product_description  \
# 37    Nike Men's Hypervenom Phantom Premium FG Socc
# 387   Nike Men's Hypervenom Phantom Premium FG Socc
# 413   Nike Men's Hypervenom Phantom Premium FG Socc
# 516   Nike Men's Hypervenom Phantom Premium FG Socc
# 546   Nike Men's Hypervenom Phantom Premium FG Socc
# 933                           Callaway X Hot Driver
# 1283  Nike Men's Hypervenom Phantom Premium FG Socc
# 623              adidas Batting Helmet Hardware Kit
# ...

# %%
df_products.loc[:,['product_name','product_price']].sort_values(by='product_price',ascending=True).head()
# Out:
#                                        product_name  product_price
# 413   Nike Men's Hypervenom Phantom Premium FG Socc            0.0
# 933                           Callaway X Hot Driver            0.0
# 516   Nike Men's Hypervenom Phantom Premium FG Socc            0.0
# 387   Nike Men's Hypervenom Phantom Premium FG Socc            0.0
# 1283  Nike Men's Hypervenom Phantom Premium FG Socc            0.0

# %%
df_products.sort_values(by='product_price',ascending=False).head()
# Out:
#       product_id  product_category_id  \
# 207          208                   10
# 198          199                   10
# 65            66                    4
# 495          496                   22
# 1047        1048                   47
#
#                                        product_name product_description  \
# 207                             SOLE E35 Elliptical
# 198                              SOLE F85 Treadmill
# 65                               SOLE F85 Treadmill
# 495                              SOLE F85 Treadmill
# 1047  Spalding Beast 60" Glass Portable Basketball
#
#       product_price                                      product_image
# 207         1999.99  http://images.acmesports.sports/SOLE+E35+Ellip...
# 198         1799.99  http://images.acmesports.sports/SOLE+F85+Tread...
# 65          1799.99  http://images.acmesports.sports/SOLE+F85+Tread...
# 495         1799.99  http://images.acmesports.sports/SOLE+F85+Tread...
# ...
