# %%
! pip install azure-storage-file-datalake
# Out:
# Collecting azure-storage-file-datalake
#   Downloading azure_storage_file_datalake-12.25.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: azure-core>=1.37.0 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from azure-storage-file-datalake) (1.41.0)
# Collecting azure-storage-blob>=12.30.0 (from azure-storage-file-datalake)
#   Downloading azure_storage_blob-12.30.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from azure-storage-file-datalake) (4.15.0)
# Collecting isodate>=0.6.1 (from azure-storage-file-datalake)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.21.0 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from azure-core>=1.37.0->azure-storage-file-datalake) (2.33.1)
# Collecting cryptography>=2.1.4 (from azure-storage-blob>=12.30.0->azure-storage-file-datalake)
#   Downloading cryptography-49.0.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.3 kB)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.30.0->azure-storage-file-datalake) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.30.0->azure-storage-file-datalake) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-file-datalake) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-file-datalake) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-file-datalake) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/python-IA/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-storage-file-datalake) (2026.5.20)
# Downloading azure_storage_file_datalake-12.25.0-py3-none-any.whl (287 kB)
# Downloading azure_storage_blob-12.30.0-py3-none-any.whl (435 kB)
# Downloading cryptography-49.0.0-cp39-abi3-macosx_11_0_arm64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 37.3 MB/s  0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, cryptography, azure-storage-blob, azure-storage-file-datalake
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [azure-storage-file-datalake]age-blob]
# Successfully installed azure-storage-blob-12.30.0 azure-storage-file-datalake-12.25.0 cryptography-49.0.0 isodate-0.7.2

# %%
import pandas as pd
from azure.storage.filedatalake import DataLakeServiceClient
from io import StringIO

# %%
storageAccount = 'Nombre'
sasToken = 'SAS TOKEN DE AZURE'
container = 'nombre'
fileName = 'department.csv'

# %%
def obtenerClienteADLS():
    client = DataLakeServiceClient(
        accountURL = f'https://{storageAccount}.dfs.core.windows.net',
        credential = sasToken
    )
    return client

# %%
client = obtenerClienteADLS()
containerClient = client.get_file_system_client(file_system=container)
file = containerClient.get_file_client('fileName')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client = obtenerClienteADLS()
#       2 containerClient = client.get_file_system_client(file_system=container)
#       3 file = containerClient.get_file_client('fileName')
#
# Cell In[4], line 2, in obtenerClienteADLS()
#       1 def obtenerClienteADLS():
# ----> 2     client = DataLakeServiceClient(
#       3         accountURL = f'https://{storageAccount}.dfs.core.windows.net',
#       4         credential = sasToken
#       5     )
#       6     return client
#
# TypeError: DataLakeServiceClient.__init__() missing 1 required positional argument: 'account_url'

# %%
download = file.download_file()
download_bytes = download.readall()
file_content = download_bytes.decode('utf-8')
file_content

# %%
df = pd.read_csv(StringIO(file_content))
